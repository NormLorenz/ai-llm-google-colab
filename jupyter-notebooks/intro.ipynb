# %% [markdown]
# <a href="https://colab.research.google.com/github/NormLorenz/ai-llm-google-colab/blob/main/jupyter-notebooks/intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **bold text![DSC00917 (1).JPG](data:image/jpeg;base64,...)**

# %%
a: str = 'hello '
b: str = 'world'
print(a + b)

# %%
# Install the openai library
# % pip install openai

# Import the library
import openai

# Replace with your actual OpenAI API key
from google.colab import userdata
from openai import OpenAI

# Get the OpenAI secret
open_ai_secret = userdata.get('OPENAI_API_KEY')

# Initialize the OpenAI client
openai = OpenAI(api_key=open_ai_secret)

# Define a simple chat function
def simple_chat(prompt):
  response = openai.chat.completions.create(
      model="gpt-3.5-turbo",  # Or another suitable model
      messages=[{"role": "user", "content": prompt}]
  )
  return response.choices[0].message.content

# Example usage
user_input = input("You: ")
while user_input.lower() != "quit":
  response = simple_chat(user_input)
  print(f"AI: {response}")
  user_input = input("You: ")

print("Chat ended.")
